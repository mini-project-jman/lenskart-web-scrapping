# %%
import re
import requests
import json

# %%
r = requests.session()

# %%
html_content = r.get("https://www.lenskart.com/")

# %%
html_content.text
# Out:
# '<!DOCTYPE html><html dir="ltr" lang="en-in"><head><meta charSet="UTF-8" /><meta content="max-age=600000, private" http-equiv="Cache-Control" /><meta content="IE=edge" http-equiv="X-UA-Compatible" /><meta content="on" http-equiv="x-dns-prefetch-control" /><meta content="yes" name="full-screen" /><meta content="yes" name="apple-touch-fullscreen" /><meta content="yes" name="apple-mobile-web-app-capable" /><link rel="preconnect" href="https://dash.cloudflare.com\n" /><link rel="dns-prefetch" href="https://dash.cloudflare.com\n" /><link rel="manifest" href="/manifest.json" /><link href="https://static1.lenskart.com/media/desktop/img/Sep23/13-Sep/lenskart-logo-new-144x144.png" rel="apple-touch-icon" sizes="144x144" type="image/x-icon" /><link href="https://static1.lenskart.com/media/desktop/img/Sep23/13-Sep/lenskart-logo-new-144x144.png" rel="icon" type="image/x-icon" /><link href="https://www.lenskart.com/lenskart-favicon.ico" rel="shortcut icon" /><link href="https://www.lenskart.com/lenskart-favicon.ico" rel="icon" /><meta content="Lenskart.com" property="og:site_name" /><meta content="website" property="og:type" /><meta content="https://www.lenskart.com" property="og:url" /><meta content="Lenskart.com - Buy Eyeglasses, Sunglasses and Contact Lens Online" property="og:title" /><meta content="https://static1.lenskart.com/media/desktop/img/Sep23/13-Sep/lenskart-logo-new-144x144.png" property="og:image" /><meta content="Get Buy 1 Get 1 Free with Lenskart Gold Membership. Upto 60% OFF on first order. Order now!" property="og:description" /><meta content="app" name="twitter:card" /><meta content="@Lenskart_com" name="twitter:site" /><meta content="Get Buy 1 Get 1 Free with Lenskart Gold Membership. Upto 60% OFF on first order. Order now!" name="twitter:description" /><meta content="https://static1.lenskart.com/media/desktop/img/Sep23/13-Sep/lenskart-logo-new-144x144.png" property="twitter:image" /><meta content="in" name="twitter:app:country" /><meta content="Lenskart.com" name="twitter:app:name:iphone" /><meta content="970343205" name="twitter:app:id:iphone" /><meta content="Lenskart.com" name="twitter:app:name:ipad" /><meta content="970343205" name="twitter:app:id:ipad" /><meta content="Lenskart.com" name="twitter:app:name:googleplay" /><meta content="com.lenskart.app" name="twitter:app:id:googleplay" /><meta name="apple-mobile-web-app-status-bar-style" content="default" /><meta name="apple-mobile-web-app-title" content="Lenskart Lite" /><meta name="mobile-web-app-capable" content="yes" /><meta content="https://www.lenskart.com/" name="twitter:app:url:iphone" /><meta content="https://www.lenskart.com/" name="twitter:app:url:ipad" /><meta content="https://www.lenskart.com/" name="twitter:app:url:googleplay" /><script type="application/ld+json">{"@context":"https://schema.org","@type":"WebSite","url":"https://www.lenskart.com","potentialAction":{"@type":"SearchAction","target":"https://www.lenskart.com/search?q={search_term_string}","query-input":"required name=search_term_string"}}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"Organization","url":"https://www.lenskart.com","name":"Lenskart.com","contactPoint":{"@type":"ContactPoint","telephone":"+91-99998-99998","contactType":"Customer Service"},"sameAs":[],"logo":"https://static.lenskart.com/media/mobile/images/lenskart_icon_512X512.png"}</script><meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, viewport-fit=cover, minimal-ui, user-scalable=no" /><title>Eyeglasses, Sunglasses, Contact Lens Online - Lenskart IN</title><meta name="description" content="Shop online for Eyeglasses, Sunglasses, Contact Lenses, and Prescription glasses at the best prices." /><link rel="alternate" href="https://www.lenskart.com/en-us" hrefLang="en-us" /><link rel="alternate" href="https://www.lenskart.com/en-ae" hrefLang="en-ae" /><link rel="alternate" href="https://www.lenskart.com/en-sa" hrefLang="en-sa" /><link rel="alternate ...

# %%
with open('html_content.txt', 'w', encoding='utf-8') as f:
    f.write(html_content.text)

# %%
pattern_link = r'<a class="LastRowLink--slw9ry hhBfjB getGaData.*?="(.*?)"'

# %%
pagetemp_products = re.findall(pattern_link, html_content.text)
pagetemp_products
# Out:
# ['/eyeglasses.html',
#  '/eyeglasses/collections/all-computer-glasses.html',
#  '/eyeglasses/promotions/all-kids-eyeglasses.html',
#  '/contact-lenses.html',
#  '/sunglasses.html',
#  'lrd4',
#  'lrd9']

# %%
for i in (pagetemp_products):
    print('https://www.lenskart.com'+i)
# Out:
# https://www.lenskart.com/eyeglasses.html
# https://www.lenskart.com/eyeglasses/collections/all-computer-glasses.html
# https://www.lenskart.com/eyeglasses/promotions/all-kids-eyeglasses.html
# https://www.lenskart.com/contact-lenses.html
# https://www.lenskart.com/sunglasses.html
# https://www.lenskart.comlrd4
# https://www.lenskart.comlrd9

# %%
Api_sunglasses = r.get("https://api-gateway.juno.lenskart.com/v2/products/category/3362?page-size=1380")
Api_sunglasses.content
# Out:
# b'{"result":{"category_name":"Sunglasses","product_list":[{"id":"200379","image_url":"https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//v/i/gold-brown-gradient-full-rim-aviator-vincent-chase-polarized-vintage-vc-s11075-c11-sunglasses_g_3378_6_02_22.jpg","image_url_suffix":"/v/i/gold-brown-gradient-full-rim-aviator-vincent-chase-polarized-vintage-vc-s11075-c11-sunglasses_g_3378_6_02_22.jpg","imageUrls":[],"product_url":"https://www.lenskart.com/vincent-chase-vc-s11075-c11-sunglasses.html","color":"Gold","occasion":"Vacation","size":"Medium","width":"138 mm","suited_for":"","brand_name":"Vincent Chase Polarized","brand_name_en":"Vincent Chase Polarized","model_name":"VC S11075","prices":[{"name":"Market Price","currency_code":"INR","price":1500},{"name":"Lenskart Price","currency_code":"INR","price":1500}],"is_tbyb":false,"tags":"Wired up","color_options":[],"totalColorAvailable":0,"is_ditto":true,"classification":"sunglasses","specifications":[],"wishlistCount":0,"purchaseCount":8079,"avgRating":4.4,"totalNoOfRatings":"190","hashtagList":[{"name":"Medium","id":11341,"property":"frame_size_id"},{"name":"Aviator","id":11348,"property":"frame_shape_id"},{"name":"Vincent Chase Polarized","id":20958,"property":"brandname_id"},{"name":"Full Rim","id":11370,"property":"frametype_id"}],"offerName":"VCSUN","cmsLinkAndroid":"https://www.lenskart.com/cms-frame-size","cmsLinkIos":"https://www.lenskart.com/cms-frame-size-ios","arModelAndroidUrl":"https://3d-asset-lookr-new.s3.ap-southeast-1.amazonaws.com/frameassets/200379/android/sku_200379.glb","arModelIOSUrl":"https://3d-asset-lookr-new.s3.ap-southeast-1.amazonaws.com/frameassets/200379/ios/sku_200379.scn","arModelOriginalUrl":"https://3d-asset-lookr-new.s3.ap-southeast-1.amazonaws.com/frameassets/200379/orignal/sku_200379.glb","qty":3040,"frameColorImage":"https://ds-static.lenskart.com/product_color_bubble_images/200379_bubble.png","subCollection":"Wired up","subCollectionId":25029,"relatedItems":[],"isCygnusEnabled":true,"isCashbackApplicable":false,"searchProductName":"Gold Aviator Full Rim Sunglasses","prescriptionType":[]},{"id":"206743","image_url":"https://static5.lenskart.com/media/catalog/product/pro/1/thumbnail/628x301/9df78eab33525d08d6e5fb8d27136e95//v/i/gold-brown-brown-rimless-square-vincent-chase-met-effect-vc-s15397-c3-sunglasses_g_1017_02_02_23.jpg","image_url_suffix":"/v/i/gold-brown-brown-rimless-square-vincent-chase-met-effect-vc-s15397-c3-sunglasses_g_1017_02_02_23.jpg","imageUrls":[],"product_url":"https://www.lenskart.com/vincent-chase-vc-s15397-c3-sunglasses.html","color":"Gold Black","occasion":"Vacation","size":"Wide","width":"142 mm","suited_for":"","brand_name":"Vincent Chase","brand_name_en":"Vincent Chase","model_name":"VC S15397","prices":[{"name":"Market Price","currency_code":"INR","price":2000},{"name":"Lenskart Price","currency_code":"INR","price":2000}],"is_tbyb":false,"tags":"Met Effect","color_options":[],"totalColorAvailable":0,"is_ditto":true,"classification":"sunglasses","specifications":[],"wishlistCount":0,"purchaseCount":3508,"avgRating":0.0,"hashtagList":[{"name":"Wide","id":24069,"property":"frame_size_id"},{"name":"Rectangle/ Square","id":23902,"property":"frame_shape_id"},{"name":"Vincent Chase","id":10733,"property":"brandname_id"},{"name":"Rimless","id":11372,"property":"frametype_id"}],"offerName":"VCSUN","cmsLinkAndroid":"https://www.lenskart.com/cms-frame-size","cmsLinkIos":"https://www.lenskart.com/cms-frame-size-ios","arModelAndroidUrl":"https://lookr-static.lenskart.com/frameassets/206743/android/sku_206743.glb","arModelIOSUrl":"https://lookr-static.lenskart.com/frameassets/206743/ios/sku_206743.scn","arModelOriginalUrl":"https://lookr-static.lenskart.com/frameassets/206743/orignal/sku_206743.glb","qty":4536,"frameColorImage":"https://ds-static.lenskart.com/product_color_bubble_images/206743_bubble.png","subCollection":"MET EFFECT","subCollectionId":25043,"inclusiveText":"" ...

# %%
# Specify the file path for the new JSON file
json_file_path = "final_data.json"

    # Save the beautified JSON data to a new file
with open(json_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, indent=4, ensure_ascii=False)
    print(f"Beautified data saved to {json_file_path}")
# Out:
# Beautified data saved to final_data.json

# %%
# Specify the path to your JSON file
json_file_path = "final_data.json"

# Load data from the JSON file
with open(json_file_path, 'r', encoding='utf-8') as json_file:
    loaded_data = json.load(json_file)

# Extract the necessary information
category_name = loaded_data["result"]["category_name"]
product_list = loaded_data["result"]["product_list"]

# Create a list to store data for all products
all_products_data = []

# Loop through all the products
for product_data in product_list:
    # Append the product data to the list
    all_products_data.append(product_data)

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(all_products_data)

# Save the DataFrame to a CSV file
csv_file_path = "all_products_data.csv"
df.to_csv(csv_file_path, index=False)

print(f"Data saved to {csv_file_path}")
# Out:
# Data saved to all_products_data.csv

# %%
# !pip install openpyxl

# Convert the list of dictionaries to a Pandas DataFrame
df = pd.DataFrame(all_products_data)

# Save the DataFrame to an Excel file
xlsx_file_path = "all_products_data.xlsx"
df.to_excel(xlsx_file_path, index=False)

print(f"Data saved to {xlsx_file_path}")
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\MananJain\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Data saved to all_products_data.xlsx

# %%
# Save the DataFrame to a CSV file
csv_file_path = "products_data.csv"
df = pd.read_csv(csv_file_path)
df
# Out:
#           id                                          image_url  \
# 0     146012  https://static5.lenskart.com/media/catalog/pro...
# 1     216521  https://static5.lenskart.com/media/catalog/pro...
# 2     217261  https://static5.lenskart.com/media/catalog/pro...
# 3     216712  https://static5.lenskart.com/media/catalog/pro...
# 4     201333  https://static5.lenskart.com/media/catalog/pro...
# ...      ...                                                ...
# 4657  134764  https://static5.lenskart.com/media/catalog/pro...
# 4658  131274  https://static5.lenskart.com/media/catalog/pro...
# 4659  131500  https://static5.lenskart.com/media/catalog/pro...
# 4660  123887  https://static5.lenskart.com/media/catalog/pro...
# 4661  131652  https://static5.lenskart.com/media/catalog/pro...
#
#                                        image_url_suffix imageUrls  \
# 0     /l/i/transparent-gold-full-rim-rectangle-lensk...        []
# 1     /l/i/lenskart-air-la-e15417-w-c1-eyeglasses_cs...        []
# 2     /l/i/lenskart-hustlr-lh-e16985-w-c5-eyeglasses...        []
# 3     /l/i/flamingo-full-rim-wayfarer-lenskart-air-h...        []
# 4     /l/i/lenskart-air-la-e13068-c6-eyeglasses_g_48...        []
# ...                                                 ...       ...
# 4657  /v/i/vincent-chase-vc-e12404-c2-eyeglasses_g_6...        []
# 4658  /j/o/john-jacobs-jj-e11736-c1-eyeglasses_G_034...        []
# 4659  /v/i/vincent-chase-vc-e11797-c3-eyeglasses_vin...        []
# 4660  /v/i/Matte-Black-Grey-Green-Full-Rim-Wayfarer-...        []
# 4661  /j/o/john-jacobs-jj-e11209-half-rim-rectangle-...        []
#
#                                             product_url        color    size  \
# 0     https://www.lenskart.com/lenskart-air-la-e1351...  Transparent  Medium
# 1     https://www.lenskart.com/lenskart-hustlr-la-e1...   Ocean Blue  Medium
# 2     https://www.lenskart.com/lenskart-hustlr-lh-e1...  Transparent  Medium
# 3     https://www.lenskart.com/lenskart-la-e15417-w-...         Pink  Medium
# 4     https://www.lenskart.com/lenskart-air-la-e1306...         Grey  Medium
# ...                                                 ...          ...     ...
# 4657  https://www.lenskart.com/blue-full-rim-rectang...         Blue  Medium
# 4658  https://www.lenskart.com/john-jacobs-jj-e11736...        Black    Wide
# 4659  https://www.lenskart.com/vincent-chase-vc-e117...         Blue  Medium
# 4660  https://www.lenskart.com/matte-black-grey-gree...        Black    Wide
# 4661  https://www.lenskart.com/john-jacobs-jj-e11209...     Gunmetal  Medium
#
#        width               brand_name            brand_name_en  ...  \
# 0     134 mm             Lenskart Air             Lenskart Air  ...
# 1     139 mm          Lenskart Hustlr          Lenskart Hustlr  ...
# 2     139 mm          Lenskart Hustlr          Lenskart Hustlr  ...
# 3     139 mm          Lenskart Hustlr          Lenskart Hustlr  ...
# 4     134 mm             Lenskart Air             Lenskart Air  ...
# ...      ...                      ...                      ...  ...
# 4657  137 mm            Vincent Chase            Vincent Chase  ...
# 4658  140 mm              John Jacobs              John Jacobs  ...
# 4659  134 mm            Vincent Chase            Vincent Chase  ...
# 4660  143 mm  Vincent Chase Polarized  Vincent Chase Polarized  ...
# 4661  136 mm              John Jacobs              John Jacobs  ...
#
#      prescriptionType  occasion suited_for  inclusiveText clUsage  \
# 0                  []       NaN        NaN            NaN     NaN
# 1                  []       NaN        NaN            NaN     NaN
# 2                  []       NaN        NaN            NaN     NaN
# 3                  []       NaN        NaN            NaN     NaN
# 4                  []       NaN        NaN            NaN     NaN
# ...               ...       ...        ...            ...     ...
# 4657               []       NaN        NaN            NaN     NaN
# 4658               []   Working        NaN            NaN     NaN
# 4659               []       NaN        NaN            NaN     NaN
# 4660               []  Vacation        NaN            NaN     NaN
# 4661               []  Everyday        NaN            NaN     NaN
#
#      tryOnImageUrl  offer_image  isCombo comboImageUrl comboDescription
# 0              NaN          NaN      NaN           NaN              NaN
# 1              NaN          NaN      NaN           NaN              NaN
# 2              NaN          NaN      NaN           NaN              NaN
# 3              NaN          NaN      NaN           NaN              NaN
# 4              NaN          NaN      NaN           NaN              NaN
# ...            ...          ...      ...           ...              ...
# 4657           NaN          NaN      NaN           NaN              NaN
# 4658           NaN          NaN      NaN           NaN              NaN
# 4659           NaN          NaN      NaN           NaN              NaN
# 4660           NaN          NaN      NaN           NaN              NaN
# 4661           NaN          NaN      NaN           NaN              NaN
#
# [4662 rows x 50 columns]

# %%
# Specify the column containing the JSON data
json_column_name = 'prices'  # Replace 'your_column_name' with the actual column name

# Function to extract prices for 'Market Price' and 'Lenskart Price'
def extract_prices(json_str):
    data_list = json.loads(json_str.replace("'", "\""))
    market_price = next((item['price'] for item in data_list if item['name'] == 'Market Price'), None)
    lenskart_price = next((item['price'] for item in data_list if item['name'] == 'Lenskart Price'), None)
    return pd.Series({'Market_Price': market_price, 'Lenskart_Price': lenskart_price})

# Apply the function to the specified column and create new columns with the extracted prices
df[['Market_Price', 'Lenskart_Price']] = df[json_column_name].apply(extract_prices)
df = df.drop('prices',axis=1)
# Print the updated DataFrame
print(df)

# Save the updated DataFrame to a new CSV file
df.to_csv('output_file.csv', index=False)
# Out:
#           id                                          image_url  \
# 0     146012  https://static5.lenskart.com/media/catalog/pro...
# 1     216521  https://static5.lenskart.com/media/catalog/pro...
# 2     217261  https://static5.lenskart.com/media/catalog/pro...
# 3     216712  https://static5.lenskart.com/media/catalog/pro...
# 4     201333  https://static5.lenskart.com/media/catalog/pro...
# ...      ...                                                ...
# 4657  134764  https://static5.lenskart.com/media/catalog/pro...
# 4658  131274  https://static5.lenskart.com/media/catalog/pro...
# 4659  131500  https://static5.lenskart.com/media/catalog/pro...
# 4660  123887  https://static5.lenskart.com/media/catalog/pro...
# 4661  131652  https://static5.lenskart.com/media/catalog/pro...
#
#                                        image_url_suffix imageUrls  \
# 0     /l/i/transparent-gold-full-rim-rectangle-lensk...        []
# 1     /l/i/lenskart-air-la-e15417-w-c1-eyeglasses_cs...        []
# 2     /l/i/lenskart-hustlr-lh-e16985-w-c5-eyeglasses...        []
# 3     /l/i/flamingo-full-rim-wayfarer-lenskart-air-h...        []
# 4     /l/i/lenskart-air-la-e13068-c6-eyeglasses_g_48...        []
# ...                                                 ...       ...
# 4657  /v/i/vincent-chase-vc-e12404-c2-eyeglasses_g_6...        []
# 4658  /j/o/john-jacobs-jj-e11736-c1-eyeglasses_G_034...        []
# 4659  /v/i/vincent-chase-vc-e11797-c3-eyeglasses_vin...        []
# 4660  /v/i/Matte-Black-Grey-Green-Full-Rim-Wayfarer-...        []
# 4661  /j/o/john-jacobs-jj-e11209-half-rim-rectangle-...        []
#
#                                             product_url        color    size  \
# 0     https://www.lenskart.com/lenskart-air-la-e1351...  Transparent  Medium
# 1     https://www.lenskart.com/lenskart-hustlr-la-e1...   Ocean Blue  Medium
# 2     https://www.lenskart.com/lenskart-hustlr-lh-e1...  Transparent  Medium
# 3     https://www.lenskart.com/lenskart-la-e15417-w-...         Pink  Medium
# 4     https://www.lenskart.com/lenskart-air-la-e1306...         Grey  Medium
# ...                                                 ...          ...     ...
# 4657  https://www.lenskart.com/blue-full-rim-rectang...         Blue  Medium
# 4658  https://www.lenskart.com/john-jacobs-jj-e11736...        Black    Wide
# 4659  https://www.lenskart.com/vincent-chase-vc-e117...         Blue  Medium
# 4660  https://www.lenskart.com/matte-black-grey-gree...        Black    Wide
# 4661  https://www.lenskart.com/john-jacobs-jj-e11209...     Gunmetal  Medium
#
#        width               brand_name            brand_name_en  ...  \
# 0     134 mm             Lenskart Air             Lenskart Air  ...
# 1     139 mm          Lenskart Hustlr          Lenskart Hustlr  ...
# 2     139 mm          Lenskart Hustlr          Lenskart Hustlr  ...
# 3     139 mm          Lenskart Hustlr          Lenskart Hustlr  ...
# 4     134 mm             Lenskart Air             Lenskart Air  ...
# ...      ...                      ...                      ...  ...
# 4657  137 mm            Vincent Chase            Vincent Chase  ...
# 4658  140 mm              John Jacobs              John Jacobs  ...
# 4659  134 mm            Vincent Chase            Vincent Chase  ...
# 4660  143 mm  Vincent Chase Polarized  Vincent Chase Polarized  ...
# 4661  136 mm              John Jacobs              John Jacobs  ...
#
#      suited_for inclusiveText  clUsage tryOnImageUrl offer_image  isCombo  \
# 0           NaN           NaN      NaN           NaN         NaN      NaN
# 1           NaN           NaN      NaN           NaN         NaN      NaN
# 2           NaN           NaN      NaN           NaN         NaN      NaN
# 3           NaN           NaN      NaN           NaN         NaN      NaN
# 4           NaN           NaN      NaN           NaN         NaN      NaN
# ...         ...           ...      ...           ...         ...      ...
# 4657        NaN           NaN      NaN           NaN         NaN      NaN
# 4658        NaN           NaN      NaN           NaN         NaN      NaN
# 4659        NaN           NaN      NaN           NaN         NaN      NaN
# 4660        NaN           NaN      NaN           NaN         NaN      NaN
# 4661        NaN           NaN      NaN           NaN         NaN      NaN
#
#       comboImageUrl comboDescription Market_Price  Lenskart_Price
# 0               NaN              NaN         1700            1700
# 1               NaN              NaN         1700            1700
# 2               NaN              NaN         1700            1700
# 3               NaN              NaN         1700            1700
# 4               NaN              NaN         1700            1700
# ...             ...              ...          ...             ...
# 4657            NaN              NaN         1700            1700
# 4658            NaN              NaN         3500            3500
# 4659            NaN              NaN         1700            1700
# 4660            NaN              NaN         1500            1500
# 4661            NaN              NaN         5000            5000
#
# [4662 rows x 51 columns]

# %%
# Specify the column containing the JSON data
json_column_name = 'hashtagList'  # Replace 'hashtagList' with the actual column name

# Function to extract 'name' values and join them into a string
def extract_names(json_str):
    data_list = json.loads(json_str.replace("'", "\""))
    name_values = [item.get('name', '') for item in data_list]
    return ",".join(name_values)

# Apply the function to the specified column and create a new column with the converted values
df[json_column_name] = df[json_column_name].apply(extract_names)


# Print the updated DataFrame
print(df)

# Save the updated DataFrame to a new CSV file
df.to_csv('output_file.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[100], line 11
#       8     return ",".join(name_values)
#      10 # Apply the function to the specified column and create a new column with the converted values
# ---> 11 df[json_column_name] = df[json_column_name].apply(extract_names)
#      14 # Print the updated DataFrame
#      15 print(df)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[100], line 6, in extract_names(json_str)
#       5 def extract_names(json_str):
# ----> 6     data_list = json.loads(json_str.replace("'", "\""))
#       7     name_values = [item.get('name', '') for item in data_list]
#       8     return ",".join(name_values)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df1 =pd.read_csv('finalLensKartData.csv')

# %%
df1['Discount_Percentage'] = round(((df1['Market_Price'] - df1['Lenskart_Price']) / df1['Market_Price']) * 100,0)

# %%
df1['Discount_Percentage'].unique()
# Out:
# array([  0.,  27.,  51.,  31.,  20.,  38.,  16.,   4.,   9.,  52.,  80.,
#         46.,   1.,  49.,  34., -50.,  54.,  33.,  84.,  17.,  14.,  29.,
#         24.,  23.,   7.,  12.,  18.,   8.,  21.,   5.,  43.,  13.,   3.,
#         10.,  58.,  45.,  22.,  50.,   2.,  11.,  67.,  60.,  40.,  15.,
#         56.,  30.,  62.,  72.,  19.,  37.,  77.])

# %%
df1.to_csv('output_file1.csv', index=False)
