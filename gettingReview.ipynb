# %%
# !pip3 install pandas
# !pip3 install bs4
# Out:
# Collecting bs4
#   Obtaining dependency information for bs4 from https://files.pythonhosted.org/packages/51/bb/bf7aab772a159614954d84aa832c129624ba6c32faa559dfb200a534e50b/bs4-0.0.2-py2.py3-none-any.whl.metadata
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\envs\mlenv\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\envs\mlenv\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
import pandas as pd
import requests


# Load CSV into DataFrame
df = pd.read_csv("products_data.csv")

# Display the first few rows of the DataFrame to verify it loaded correctly
df.head()
# Out:
#        id                                          image_url  \
# 0  146012  https://static5.lenskart.com/media/catalog/pro...
# 1  216521  https://static5.lenskart.com/media/catalog/pro...
# 2  217261  https://static5.lenskart.com/media/catalog/pro...
# 3  216712  https://static5.lenskart.com/media/catalog/pro...
# 4  201333  https://static5.lenskart.com/media/catalog/pro...
#
#                                     image_url_suffix imageUrls  \
# 0  /l/i/transparent-gold-full-rim-rectangle-lensk...        []
# 1  /l/i/lenskart-air-la-e15417-w-c1-eyeglasses_cs...        []
# 2  /l/i/lenskart-hustlr-lh-e16985-w-c5-eyeglasses...        []
# 3  /l/i/flamingo-full-rim-wayfarer-lenskart-air-h...        []
# 4  /l/i/lenskart-air-la-e13068-c6-eyeglasses_g_48...        []
#
#                                          product_url        color    size  \
# 0  https://www.lenskart.com/lenskart-air-la-e1351...  Transparent  Medium
# 1  https://www.lenskart.com/lenskart-hustlr-la-e1...   Ocean Blue  Medium
# 2  https://www.lenskart.com/lenskart-hustlr-lh-e1...  Transparent  Medium
# 3  https://www.lenskart.com/lenskart-la-e15417-w-...         Pink  Medium
# 4  https://www.lenskart.com/lenskart-air-la-e1306...         Grey  Medium
#
#     width       brand_name    brand_name_en  ... prescriptionType occasion  \
# 0  134 mm     Lenskart Air     Lenskart Air  ...               []      NaN
# 1  139 mm  Lenskart Hustlr  Lenskart Hustlr  ...               []      NaN
# 2  139 mm  Lenskart Hustlr  Lenskart Hustlr  ...               []      NaN
# 3  139 mm  Lenskart Hustlr  Lenskart Hustlr  ...               []      NaN
# 4  134 mm     Lenskart Air     Lenskart Air  ...               []      NaN
#
#   suited_for  inclusiveText clUsage tryOnImageUrl  offer_image  isCombo  \
# 0        NaN            NaN     NaN           NaN          NaN      NaN
# 1        NaN            NaN     NaN           NaN          NaN      NaN
# 2        NaN            NaN     NaN           NaN          NaN      NaN
# 3        NaN            NaN     NaN           NaN          NaN      NaN
# 4        NaN            NaN     NaN           NaN          NaN      NaN
#
#   comboImageUrl comboDescription
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3           NaN              NaN
# 4           NaN              NaN
#
# [5 rows x 50 columns]

# %%
products_id = df['id']
products_id
# Out:
# 0       146012
# 1       216521
# 2       217261
# 3       216712
# 4       201333
#          ...
# 4479    138423
# 4480    138327
# 4481    135530
# 4482    134149
# 4483    131500
# Name: id, Length: 4484, dtype: int64

# %%
products_id=[146012,216521,217261,216712]
reviews_data=[]
def scrape_reviews(id):
    reviews_api=f'https://api-gateway.juno.lenskart.com/v2/products/product/{id}/review?count=10000&page=1'
    response = requests.get(reviews_api)
    if response.status_code == 200:
        data = response.json()
        reviews_data = data['result']['review']['reviews']

# Creating DataFrame
        reviews_df = pd.DataFrame(reviews_data)
        
        # Adding constant product id
        reviews_df['productId'] = id
        print(reviews_df)
# Displaying DataFrame
        print(reviews_df)
    else:
        print(f"Failed to fetch reviews for {reviews_api}")

# Scrape reviews for each product link
for id in products_id:
    scrape_reviews(id)
# Out:
#       reviewId         reviewTitle  \
# 0    544416668         nicely best
# 1    543539224                Good
# 2    542513826             Awesome
# 3    541348170                   👍
# 4    541347938                  👍👌
# ..         ...                 ...
# 141  232451425              thanks
# 142  231881039  Completely perfect
# 143  229700312        got for free
# 144  229515835        good product
# 145  229496373   Nice frame sturdy
#
#                                           reviewDetail   reviewee noOfStars  \
# 0                                                 best     kamal          5
# 1    Everything is good except the box, it smells l...  Krrish K.         4
# 2                                    very perfect ❤️‍🩹     PRATIK         5
# 3            product is nice but delivery is very late   Aryan j.         5
# 4                                      product is nice   Aryan j.         5
# ..                                                 ...        ...       ...
# 141                                          satisfied     Dr. R.         5
# 142                      Nice frame and perfect lenses   Kapil S.         5
# 143  crystal clear lenses perfect fit accurate diop...    Aniket          5
# 144                             product is comfortable    tharun          4
# 145                   Looks good on face can recommend   Sidharth         5
#
#                reviewDate       reviewerType images  productId
# 0    2024-02-14T09:17:42Z     anonymous_user     []     146012
# 1    2024-02-11T12:52:05Z     anonymous_user     []     146012
# 2    2024-02-08T11:37:25Z     anonymous_user     []     146012
# 3    2024-02-02T14:25:50Z     anonymous_user     []     146012
# 4    2024-02-02T14:24:23Z     anonymous_user     []     146012
# ..                    ...                ...    ...        ...
# 141  2021-02-18T12:43:06Z     anonymous_user     []     146012
# 142  2021-02-15T08:12:59Z  verified_reviewer     []     146012
# 143  2021-02-01T09:09:42Z     anonymous_user     []     146012
# 144  2021-01-30T11:51:09Z  verified_reviewer     []     146012
# 145  2021-01-30T06:50:52Z     verified_buyer     []     146012
#
# [146 rows x 9 columns]
#       reviewId         reviewTitle  \
# 0    544416668         nicely best
# 1    543539224                Good
# 2    542513826             Awesome
# 3    541348170                   👍
# 4    541347938                  👍👌
# ..         ...                 ...
# 141  232451425              thanks
# 142  231881039  Completely perfect
# 143  229700312        got for free
# 144  229515835        good product
# 145  229496373   Nice frame sturdy
#
#                                           reviewDetail   reviewee noOfStars  \
# 0                                                 best     kamal          5
# 1    Everything is good except the box, it smells l...  Krrish K.         4
# 2                                    very perfect ❤️‍🩹     PRATIK         5
# 3            product is nice but delivery is very late   Aryan j.         5
# 4                                      product is nice   Aryan j.         5
# ..                                                 ...        ...       ...
# 141                                          satisfied     Dr. R.         5
# 142                      Nice frame and perfect lenses   Kapil S.         5
# 143  crystal clear lenses perfect fit accurate diop...    Aniket          5
# 144                             product is comfortable    tharun          4
# 145                   Looks good on face can recommend   Sidharth         5
#
#                reviewDate       reviewerType images  productId
# 0    2024-02-14T09:17:42Z     anonymous_user     []     146012
# 1    2024-02-11T12:52:05Z     anonymous_user     []     146012
# 2    2024-02-08T11:37:25Z     anonymous_user     []     146012
# 3    2024-02-02T14:25:50Z     anonymous_user     []     146012
# 4    2024-02-02T14:24:23Z     anonymous_user     []     146012
# ..                    ...                ...    ...        ...
# 141  2021-02-18T12:43:06Z     anonymous_user     []     146012
# 142  2021-02-15T08:12:59Z  verified_reviewer     []     146012
# 143  2021-02-01T09:09:42Z     anonymous_user     []     146012
# 144  2021-01-30T11:51:09Z  verified_reviewer     []     146012
# 145  2021-01-30T06:50:52Z     verified_buyer     []     146012
#
# [146 rows x 9 columns]
#       reviewId         reviewTitle  \
# 0    552567835        good product
# 1    552373411           very nice
# 2    552343654        nice product
# 3    549914752   worth every rupee
# 4    549626450       Green hustler
# ..         ...                 ...
# 283  424231400          very Noice
# 284  423520346                good
# 285  422345438       awesome 5/5 👍
# 286  422344926  frame with glasses
# 287  421289500           excellent
#
#                                           reviewDetail     reviewee noOfStars  \
# 0                     nice fitting good quality lenses    kartik J.         5
# 1                                       very very good     parth g.         5
# 2             very light, comfortable and stylish look      Aman K.         5
# 3    material is light weight.\nThis glasses don't ...      kalash          5
# 4    good in quality but I ordered military green a...     pooja k.         4
# ..                                                 ...          ...       ...
# 283                                       very noiceee      aditya          5
# 284                         product is of good quality  Firasath A.         5
# 285         looks very good , light weighted, loved it  Bhavantu v.         5
# 286  1-looks really awesome, 2-light weighted loved it      jack s.         5
# 287  excellent frame with accurate power and cleari...         TK           5
#
#                reviewDate       reviewerType images  productId
# 0    2024-03-03T09:39:39Z     anonymous_user     []     216521
# 1    2024-03-02T15:27:54Z     anonymous_user     []     216521
# 2    2024-03-02T09:34:33Z     anonymous_user     []     216521
# 3    2024-02-26T14:55:17Z     anonymous_user     []     216521
# 4    2024-02-25T06:20:38Z     anonymous_user     []     216521
# ..                    ...                ...    ...        ...
# 283  2022-12-10T04:48:28Z     anonymous_user     []     216521
# 284  2022-12-07T12:54:44Z  verified_reviewer     []     216521
# 285  2022-12-02T17:45:14Z  verified_reviewer     []     216521
# 286  2022-12-02T17:37:30Z     anonymous_user     []     216521
# 287  2022-11-27T06:33:57Z  verified_reviewer     []     216521
#
# [288 rows x 9 columns]
#       reviewId         reviewTitle  \
# 0    552567835        good product
# 1    552373411           very nice
# 2    552343654        nice product
# 3    549914752   worth every rupee
# 4    549626450       Green hustler
# ..         ...                 ...
# 283  424231400          very Noice
# 284  423520346                good
# 285  422345438       awesome 5/5 👍
# 286  422344926  frame with glasses
# 287  421289500           excellent
#
#                                           reviewDetail     reviewee noOfStars  \
# 0                     nice fitting good quality lenses    kartik J.         5
# 1                                       very very good     parth g.         5
# 2             very light, comfortable and stylish look      Aman K.         5
# 3    material is light weight.\nThis glasses don't ...      kalash          5
# 4    good in quality but I ordered military green a...     pooja k.         4
# ..                                                 ...          ...       ...
# 283                                       very noiceee      aditya          5
# 284                         product is of good quality  Firasath A.         5
# 285         looks very good , light weighted, loved it  Bhavantu v.         5
# 286  1-looks really awesome, 2-light weighted loved it      jack s.         5
# 287  excellent frame with accurate power and cleari...         TK           5
#
#                reviewDate       reviewerType images  productId
# 0    2024-03-03T09:39:39Z     anonymous_user     []     216521
# 1    2024-03-02T15:27:54Z     anonymous_user     []     216521
# 2    2024-03-02T09:34:33Z     anonymous_user     []     216521
# 3    2024-02-26T14:55:17Z     anonymous_user     []     216521
# 4    2024-02-25T06:20:38Z     anonymous_user     []     216521
# ..                    ...                ...    ...        ...
# 283  2022-12-10T04:48:28Z     anonymous_user     []     216521
# 284  2022-12-07T12:54:44Z  verified_reviewer     []     216521
# 285  2022-12-02T17:45:14Z  verified_reviewer     []     216521
# 286  2022-12-02T17:37:30Z     anonymous_user     []     216521
# 287  2022-11-27T06:33:57Z  verified_reviewer     []     216521
#
# [288 rows x 9 columns]
# Empty DataFrame
# Columns: [productId]
# Index: []
# Empty DataFrame
# Columns: [productId]
# Index: []
#       reviewId         reviewTitle  \
# 0    552567835        good product
# 1    552373411           very nice
# 2    552343654        nice product
# 3    549914752   worth every rupee
# 4    549626450       Green hustler
# ..         ...                 ...
# 283  424231400          very Noice
# 284  423520346                good
# 285  422345438       awesome 5/5 👍
# 286  422344926  frame with glasses
# 287  421289500           excellent
#
#                                           reviewDetail     reviewee noOfStars  \
# 0                     nice fitting good quality lenses    kartik J.         5
# 1                                       very very good     parth g.         5
# 2             very light, comfortable and stylish look      Aman K.         5
# 3    material is light weight.\nThis glasses don't ...      kalash          5
# 4    good in quality but I ordered military green a...     pooja k.         4
# ..                                                 ...          ...       ...
# 283                                       very noiceee      aditya          5
# 284                         product is of good quality  Firasath A.         5
# 285         looks very good , light weighted, loved it  Bhavantu v.         5
# 286  1-looks really awesome, 2-light weighted loved it      jack s.         5
# 287  excellent frame with accurate power and cleari...         TK           5
#
#                reviewDate       reviewerType images  productId
# 0    2024-03-03T09:39:39Z     anonymous_user     []     216712
# 1    2024-03-02T15:27:54Z     anonymous_user     []     216712
# 2    2024-03-02T09:34:33Z     anonymous_user     []     216712
# 3    2024-02-26T14:55:17Z     anonymous_user     []     216712
# 4    2024-02-25T06:20:38Z     anonymous_user     []     216712
# ..                    ...                ...    ...        ...
# 283  2022-12-10T04:48:28Z     anonymous_user     []     216712
# 284  2022-12-07T12:54:44Z  verified_reviewer     []     216712
# 285  2022-12-02T17:45:14Z  verified_reviewer     []     216712
# 286  2022-12-02T17:37:30Z     anonymous_user     []     216712
# 287  2022-11-27T06:33:57Z  verified_reviewer     []     216712
#
# [288 rows x 9 columns]
#       reviewId         reviewTitle  \
# 0    552567835        good product
# 1    552373411           very nice
# 2    552343654        nice product
# 3    549914752   worth every rupee
# 4    549626450       Green hustler
# ..         ...                 ...
# 283  424231400          very Noice
# 284  423520346                good
# 285  422345438       awesome 5/5 👍
# 286  422344926  frame with glasses
# 287  421289500           excellent
#
#                                           reviewDetail     reviewee noOfStars  \
# 0                     nice fitting good quality lenses    kartik J.         5
# 1                                       very very good     parth g.         5
# 2             very light, comfortable and stylish look      Aman K.         5
# 3    material is light weight.\nThis glasses don't ...      kalash          5
# 4    good in quality but I ordered military green a...     pooja k.         4
# ..                                                 ...          ...       ...
# 283                                       very noiceee      aditya          5
# 284                         product is of good quality  Firasath A.         5
# 285         looks very good , light weighted, loved it  Bhavantu v.         5
# 286  1-looks really awesome, 2-light weighted loved it      jack s.         5
# 287  excellent frame with accurate power and cleari...         TK           5
#
#                reviewDate       reviewerType images  productId
# 0    2024-03-03T09:39:39Z     anonymous_user     []     216712
# 1    2024-03-02T15:27:54Z     anonymous_user     []     216712
# 2    2024-03-02T09:34:33Z     anonymous_user     []     216712
# 3    2024-02-26T14:55:17Z     anonymous_user     []     216712
# 4    2024-02-25T06:20:38Z     anonymous_user     []     216712
# ..                    ...                ...    ...        ...
# 283  2022-12-10T04:48:28Z     anonymous_user     []     216712
# 284  2022-12-07T12:54:44Z  verified_reviewer     []     216712
# 285  2022-12-02T17:45:14Z  verified_reviewer     []     216712
# 286  2022-12-02T17:37:30Z     anonymous_user     []     216712
# 287  2022-11-27T06:33:57Z  verified_reviewer     []     216712
#
# [288 rows x 9 columns]

# %%
reviews_data = []

def scrape_reviews(id):
    reviews_api = f'https://api-gateway.juno.lenskart.com/v2/products/product/{id}/review?count=10000&page=1'
    response = requests.get(reviews_api)
    if response.status_code == 200:
        data = response.json()
        for review in data['result']['review']['reviews']:
            # Fill in missing values with 'NA'
            review_filled = {key: review.get(key, 'NA') for key in ['reviewId', 'reviewTitle', 'reviewDetail', 'reviewee', 'noOfStars', 'reviewDate', 'reviewerType', 'images']}
            review_filled['productId'] = id
            reviews_data.append(review_filled)
    else:
        print(f"Failed to fetch reviews for product ID {id}")

# Scrape reviews for each product id
for id in products_id:
    scrape_reviews(id)

# Creating DataFrame
reviews_df = pd.DataFrame(reviews_data)

# Reordering columns
reviews_df = reviews_df[['productId', 'reviewee', 'noOfStars', 'reviewDetail', 'reviewDate', 'reviewTitle', 'reviewId', 'reviewerType', 'images']]

# Displaying DataFrame
print(reviews_df)
# Out:
# Failed to fetch reviews for product ID 128269
#         productId    reviewee noOfStars  \
# 0          146012      kamal          5
# 1          146012   Krrish K.         4
# 2          146012      PRATIK         5
# 3          146012    Aryan j.         5
# 4          146012    Aryan j.         5
# ...           ...         ...       ...
# 154327     131500       Anand         4
# 154328     131500  Praveen K.         5
# 154329     131500      Harish         1
# 154330     131500      Arusha         1
# 154331     131500        HARI         4
#
#                                              reviewDetail  \
# 0                                                    best
# 1       Everything is good except the box, it smells l...
# 2                                       very perfect ❤️‍🩹
# 3               product is nice but delivery is very late
# 4                                         product is nice
# ...                                                   ...
# 154327                                       Good product
# 154328                     This is a great looking frame.
# 154329                                     Size not match
# 154330  The frames are made of the poorest quality of ...
# 154331                             Good and simply superb
#
#                   reviewDate       reviewTitle   reviewId    reviewerType  \
# 0       2024-02-14T09:17:42Z       nicely best  544416668  anonymous_user
# 1       2024-02-11T12:52:05Z              Good  543539224  anonymous_user
# 2       2024-02-08T11:37:25Z           Awesome  542513826  anonymous_user
# 3       2024-02-02T14:25:50Z                 👍  541348170  anonymous_user
# 4       2024-02-02T14:24:23Z                👍👌  541347938  anonymous_user
# ...                      ...               ...        ...             ...
# 154327  2019-11-01T11:09:39Z            Review  131537860  verified_buyer
# 154328  2019-11-01T10:54:06Z        Proper fit  131535843  verified_buyer
# 154329  2019-11-01T09:34:28Z    Size not match  131525241  verified_buyer
# 154330  2019-11-01T07:44:01Z  Terrible Quality  131513448  verified_buyer
# 154331  2019-11-01T03:53:51Z            Review  131524562  verified_buyer
#
#        images
# 0          []
# 1          []
# 2          []
# 3          []
# 4          []
# ...       ...
# 154327     []
# 154328     []
# 154329     []
# 154330     []
# 154331     []
#
# [154332 rows x 9 columns]

# %%
reviews_df
# Out:
#         productId    reviewee noOfStars  \
# 0          146012      kamal          5
# 1          146012   Krrish K.         4
# 2          146012      PRATIK         5
# 3          146012    Aryan j.         5
# 4          146012    Aryan j.         5
# ...           ...         ...       ...
# 154327     131500       Anand         4
# 154328     131500  Praveen K.         5
# 154329     131500      Harish         1
# 154330     131500      Arusha         1
# 154331     131500        HARI         4
#
#                                              reviewDetail  \
# 0                                                    best
# 1       Everything is good except the box, it smells l...
# 2                                       very perfect ❤️‍🩹
# 3               product is nice but delivery is very late
# 4                                         product is nice
# ...                                                   ...
# 154327                                       Good product
# 154328                     This is a great looking frame.
# 154329                                     Size not match
# 154330  The frames are made of the poorest quality of ...
# 154331                             Good and simply superb
#
#                   reviewDate       reviewTitle   reviewId    reviewerType  \
# 0       2024-02-14T09:17:42Z       nicely best  544416668  anonymous_user
# 1       2024-02-11T12:52:05Z              Good  543539224  anonymous_user
# 2       2024-02-08T11:37:25Z           Awesome  542513826  anonymous_user
# 3       2024-02-02T14:25:50Z                 👍  541348170  anonymous_user
# 4       2024-02-02T14:24:23Z                👍👌  541347938  anonymous_user
# ...                      ...               ...        ...             ...
# 154327  2019-11-01T11:09:39Z            Review  131537860  verified_buyer
# 154328  2019-11-01T10:54:06Z        Proper fit  131535843  verified_buyer
# 154329  2019-11-01T09:34:28Z    Size not match  131525241  verified_buyer
# 154330  2019-11-01T07:44:01Z  Terrible Quality  131513448  verified_buyer
# 154331  2019-11-01T03:53:51Z            Review  131524562  verified_buyer
#
#        images
# 0          []
# 1          []
# 2          []
# 3          []
# 4          []
# ...       ...
# 154327     []
# 154328     []
# 154329     []
# 154330     []
# 154331     []
#
# [154332 rows x 9 columns]

# %%
reviews_df.to_csv('all_customers_reviews.csv', index=False)
